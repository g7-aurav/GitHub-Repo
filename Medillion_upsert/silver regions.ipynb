# %%
df = spark.read.table("medillian_upsert.bronze.region")
df.display()

# %%
df = df.drop("_rescued_data")

# %%
df.write.format("delta") \
    .mode("overwrite") \
    .saveAsTable("medillian_upsert.silver.regions")
